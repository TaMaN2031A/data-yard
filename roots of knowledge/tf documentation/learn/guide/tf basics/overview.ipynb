# %%
import tensorflow as tf
# Out:
# 2025-12-04 20:10:22.469054: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
x = tf.constant([[1., 2., 3.],
                 [4., 5., 6.]])
x, x.shape, x.dtype
# Out:
# (<tf.Tensor: shape=(2, 3), dtype=float32, numpy=
#  array([[1., 2., 3.],
#         [4., 5., 6.]], dtype=float32)>,
#  TensorShape([2, 3]),
#  tf.float32)

# %%
x + x
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 2.,  4.,  6.],
#        [ 8., 10., 12.]], dtype=float32)>

# %%
5 * x
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[ 5., 10., 15.],
#        [20., 25., 30.]], dtype=float32)>

# %%
x @ tf.transpose(x)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[14., 32.],
#        [32., 77.]], dtype=float32)>

# %%
x
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[1., 2., 3.],
#        [4., 5., 6.]], dtype=float32)>

# %%
tf.concat([x, x, x], axis=0)
# Out:
# <tf.Tensor: shape=(6, 3), dtype=float32, numpy=
# array([[1., 2., 3.],
#        [4., 5., 6.],
#        [1., 2., 3.],
#        [4., 5., 6.],
#        [1., 2., 3.],
#        [4., 5., 6.]], dtype=float32)>

# %%
tf.nn.softmax(x, axis=-1) # -1 means last dimension (least dimension)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[0.09003057, 0.24472848, 0.66524094],
#        [0.09003057, 0.24472848, 0.66524094]], dtype=float32)>

# %%
tf.nn.softmax(x, axis=1)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[0.09003057, 0.24472848, 0.66524094],
#        [0.09003057, 0.24472848, 0.66524094]], dtype=float32)>

# %%
tf.nn.softmax(x, axis=0)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[0.04742587, 0.04742587, 0.04742587],
#        [0.95257413, 0.95257413, 0.95257413]], dtype=float32)>

# %%
y = tf.constant([[[1., 2., 3.],
                 [4., 5., 6.]],
                 [[1., 2., 3.],
                 [4., 5., 6.]]])
y
# Out:
# <tf.Tensor: shape=(2, 2, 3), dtype=float32, numpy=
# array([[[1., 2., 3.],
#         [4., 5., 6.]],
#
#        [[1., 2., 3.],
#         [4., 5., 6.]]], dtype=float32)>

# %%
tf.nn.softmax(y, axis=0)
# Out:
# <tf.Tensor: shape=(2, 2, 3), dtype=float32, numpy=
# array([[[0.5, 0.5, 0.5],
#         [0.5, 0.5, 0.5]],
#
#        [[0.5, 0.5, 0.5],
#         [0.5, 0.5, 0.5]]], dtype=float32)>

# %%
tf.nn.softmax(y, axis=1)
# Out:
# <tf.Tensor: shape=(2, 2, 3), dtype=float32, numpy=
# array([[[0.04742588, 0.04742588, 0.04742588],
#         [0.95257413, 0.95257413, 0.95257413]],
#
#        [[0.04742588, 0.04742587, 0.04742587],
#         [0.95257413, 0.95257413, 0.95257413]]], dtype=float32)>

# %%
tf.nn.softmax(y, axis=2), tf.nn.softmax(y, axis=-1)
# Out:
# (<tf.Tensor: shape=(2, 2, 3), dtype=float32, numpy=
#  array([[[0.09003057, 0.24472848, 0.66524094],
#          [0.09003057, 0.24472848, 0.66524094]],
#
#         [[0.09003057, 0.24472848, 0.66524094],
#          [0.09003057, 0.24472848, 0.66524094]]], dtype=float32)>,
#  <tf.Tensor: shape=(2, 2, 3), dtype=float32, numpy=
#  array([[[0.09003057, 0.24472848, 0.66524094],
#          [0.09003057, 0.24472848, 0.66524094]],
#
#         [[0.09003057, 0.24472848, 0.66524094],
#          [0.09003057, 0.24472848, 0.66524094]]], dtype=float32)>)

# %%
tf.reduce_sum(x)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=21.0>

# %%
tf.convert_to_tensor([1, 2, 3])
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([1, 2, 3], dtype=int32)>

# %%
# بص للتكيف والسهولة
tf.reduce_sum([1, 2, 3])
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=6>

# %%
if tf.config.list_physical_devices('GPU'):
    print("TensorFlow **IS** using the GPU")
else:
    print("TensorFlow **IS** using the CPU")
# Out:
# TensorFlow **IS** using the CPU

# %%
# tf.Tensor objects are immutable
# if you wanna mutable => tf.Variable

# %%
"""
https://www.tensorflow.org/guide/basics#variables
"""
# Out:
# '\nhttps://www.tensorflow.org/guide/basics#variables\n'

# %%
var = tf.Variable([0, 0, 0.])
# Out:
# 2025-11-27 18:04:43.958701: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (100)

# %%
var
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=float32, numpy=array([0., 0., 0.], dtype=float32)>

# %%
var.assign([1, 2, 3])
# Out:
# <tf.Variable 'UnreadVariable' shape=(3,) dtype=float32, numpy=array([1., 2., 3.], dtype=float32)>

# %%
var.assign_add([1, 1, 1])
# Out:
# <tf.Variable 'UnreadVariable' shape=(3,) dtype=float32, numpy=array([2., 3., 4.], dtype=float32)>

# %%
# https://www.tensorflow.org/guide/basics#automatic_differentiation

# %% [markdown]
# Automatic differentiation

# %%
x = tf.Variable(1.0)

def f(x):
    y = x**2 + x*2 - 5
    return y

# %%
f(x)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-2.0>

# %%
with tf.GradientTape() as tape:
    y = f(x)

g_x = tape.gradient(y, x)
g_x
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=4.0>

# %%
"""
https://www.tensorflow.org/guide/basics#graphs_and_tffunction
"""
# Out:
# '\nhttps://www.tensorflow.org/guide/basics#graphs_and_tffunction\n'

# %%
@tf.function
def my_func(x):
    print('Tracing. \n')
    return tf.reduce_sum(x)

# %%
x = tf.constant([1, 2, 3])
my_func(x)
# Out:
# Tracing.
# 2025-11-30 20:17:55.964118: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (100)
# <tf.Tensor: shape=(), dtype=int32, numpy=6>

# %%
x = tf.constant([10, 9, 8])
my_func(x)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=27>

# %%
# Tracing was not printed => everything is in tf now

# %%
# new signature? new graph

# %%
x = tf.constant([10.0, 9.1, 8.2], dtype=tf.float32)
my_func(x)
# Out:
# Tracing.
# <tf.Tensor: shape=(), dtype=float32, numpy=27.299999237060547>

# %%
class MyModule(tf.Module):
    def __init__(self, value):
        self.weight = tf.Variable(value)
    @tf.function
    def multiply(self, x):
        print('Meh')
        return x * self.weight

# %%
mod = MyModule(3)
mod.multiply(tf.constant([1, 2, 3]))
# Out:
# Meh
# 2025-12-04 20:10:51.102925: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([3, 6, 9], dtype=int32)>

# %%
save_path = './saved'
tf.saved_model.save(mod, save_path)
# Out:
# Meh
# INFO:tensorflow:Assets written to: ./saved/assets
# INFO:tensorflow:Assets written to: ./saved/assets

# %%
import matplotlib
from matplotlib import pyplot as plt

matplotlib.rcParams['figure.figsize'] = [9, 6]

# %%
x = tf.linspace(-2, 2, 201)
x = tf.cast(x,tf.float32)

# %%
def f(x):
    y = x**2 + 2*x - 5
    return y

# %%
y = f(x) + tf.random.normal(shape=[201])
plt.plot(x.numpy(), y.numpy(), '.', label="Data")
plt.plot(x, f(x), label="Ground truth")

# %%
class Model(tf.Module):
    def __init__(self):
        rand_int = tf.random.uniform(shape=[3], minval=0, maxval=5, seed=22)
        self.w_q = tf.Variable(rand_int[0])
        self.w_l = tf.Variable(rand_int[1])
        self.b = tf.Variable(rand_int[2])

    @tf.function
    def __call__(self, x):
        return self.w_q * (x**2) + self.w_l * x + self.b

# %%
quad_model = Model()

# %%
def plot_preds(x, y, f, model, title):
  plt.figure()
  plt.plot(x, y, '.', label='Data')
  plt.plot(x, f(x), label='Ground truth')
  plt.plot(x, model(x), label='Predictions')
  plt.title(title)
  plt.legend()

# %%
plot_preds(x, y, f, quad_model, 'Before training')

# %%
"Given that this model is intended to predict continuous values, the mean squared error (MSE) is a good choice for the loss function."
# Out:
# 'Given that this model is intended to predict continuous values, the mean squared error (MSE) is a good choice for the loss function.'

# %%
def mse_loss(ypr, y):
    return tf.reduce_mean(tf.square(ypr - y))

# %%
batch_size = 32
dataset = tf.data.Dataset.from_tensor_slices((x, y))
dataset = dataset.shuffle(buffer_size=x.shape[0]).batch(batch_size)

# %%
epochs = 100
learning_rate = 0.01
losses = []

for epoch in range(epochs):
    for x_batch, y_batch in dataset:
        with tf.GradientTape() as tape:
            loss = mse_loss(ypr=quad_model(x_batch), y=y_batch)
        grads = tape.gradient(loss, quad_model.variables)
        for g,v in zip(grads, quad_model.variables):
            v.assign_sub(learning_rate*g)
    loss = mse_loss(quad_model(x), y)
    losses.append(loss)
    if epoch % 10 == 0:
        print(f'Mean squared error for step {epoch}: {loss.numpy():0.3f}')

print('\n')
plt.plot(range(epochs), losses)
plt.xlabel('Epochs')
plt.ylabel('Mean squared error (MSE)')
plt.title('MSE loss vs training iterations')
# Out:
# 2025-12-04 20:11:04.552751: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-12-04 20:11:04.578454: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-12-04 20:11:04.627391: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-12-04 20:11:04.718690: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Mean squared error for step 0: 58.002
# Mean squared error for step 10: 9.677
# 2025-12-04 20:11:04.916229: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Mean squared error for step 20: 4.065
# Mean squared error for step 30: 2.157
# 2025-12-04 20:11:05.272424: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Mean squared error for step 40: 1.454
# Mean squared error for step 50: 1.207
# Mean squared error for step 60: 1.121
# 2025-12-04 20:11:05.970826: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Mean squared error for step 70: 1.089
# Mean squared error for step 80: 1.078
# Mean squared error for step 90: 1.074
# Text(0.5, 1.0, 'MSE loss vs training iterations')

# %%
plot_preds(x, y, f, quad_model, 'After training')

# %%
new_model = tf.keras.Sequential([
    tf.keras.layers.Lambda(lambda x: tf.stack([x, x**2], axis=1)),
    tf.keras.layers.Dense(units=1, kernel_initializer=tf.random.normal)
])

# %%
new_model.compile(
    loss=tf.keras.losses.MSE,
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
)

# %%
history = new_model.fit(x, y,
                        epochs=100,
                        batch_size=32,
                        verbose=0,)

# %%
new_model.save('./model.keras')

# %%
plt.plot(history.history['loss'])
plt.xlabel('Epochs')
#plt.ylim([0, max(plt.ylim())])
plt.ylabel('Loss: Mean squared error (MSE)')
plt.title('Keras training progress')
# Out:
# Text(0.5, 1.0, 'Keras training progress')

# %%
plot_preds(x, y, f, new_model, 'After Training: Keras')
