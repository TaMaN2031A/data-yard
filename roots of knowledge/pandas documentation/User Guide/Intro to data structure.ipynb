# %%
import numpy as np
import pandas as pd
from pandas.core.interchange.dataframe_protocol import DataFrame

# %%
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a   -0.303398
# b    0.508840
# c    0.491365
# d   -0.093787
# e   -0.430272
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
pd.Series(np.random.randn(5))
# Out:
# 0    0.742072
# 1   -0.777971
# 2   -1.975067
# 3   -0.859669
# 4   -1.043210
# dtype: float64

# %%
d = {'b': 1, 'a': 0, 'c': 2}
pd.Series(d)
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %%
d = {'a': 0.0, 'd': 1.0, 'c': 2.0}
pd.Series(d)
# Out:
# a    0.0
# d    1.0
# c    2.0
# dtype: float64

# %%
pd.Series(d, index=['b', 'c', 'd', 'a'])
# Out:
# b    NaN
# c    2.0
# d    1.0
# a    0.0
# dtype: float64

# %%
pd.Series(5.0, index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %%
s.iloc[0]
# Out:
# np.float64(-0.30339768331665307)

# %%
s.iloc[: 3]
# Out:
# a   -0.303398
# b    0.508840
# c    0.491365
# dtype: float64

# %%
s[s > s.median()]
# Out:
# b    0.508840
# c    0.491365
# dtype: float64

# %%
s.iloc[[4, 3, 1]]
# Out:
# e   -0.430272
# d   -0.093787
# b    0.508840
# dtype: float64

# %%
np.exp(s)
# Out:
# a    0.738305
# b    1.663361
# c    1.634546
# d    0.910477
# e    0.650332
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s.array
# Out:
# <NumpyExtensionArray>
# [-0.30339768331665307,   0.5088404029232718,  0.49136491759520884,
#  -0.09378694907002535, -0.43027232063838966]
# Length: 5, dtype: float64

# %%
s.to_numpy()
# Out:
# array([-0.30339768,  0.5088404 ,  0.49136492, -0.09378695, -0.43027232])

# %%
s["a"]
# Out:
# np.float64(-0.30339768331665307)

# %%
s
# Out:
# a   -0.303398
# b    0.508840
# c    0.491365
# d   -0.093787
# e   -0.430272
# dtype: float64

# %%
s["e"] = 12

# %%
s
# Out:
# a    -0.303398
# b     0.508840
# c     0.491365
# d    -0.093787
# e    12.000000
# dtype: float64

# %%
"e" in s
# Out:
# True

# %%
"r" in s
# Out:
# False

# %%
s["r"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/ml_learning_journey/ml_learn_joy/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'r'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s["r"]
#
# ...

# %%
s.get("r")

# %%
s.get("r", np.nan)
# Out:
# nan

# %%
s + s
# Out:
# a    -0.606795
# b     1.017681
# c     0.982730
# d    -0.187574
# e    24.000000
# dtype: float64

# %%
s * 2
# Out:
# a    -0.606795
# b     1.017681
# c     0.982730
# d    -0.187574
# e    24.000000
# dtype: float64

# %%
np.exp(s)
# Out:
# a         0.738305
# b         1.663361
# c         1.634546
# d         0.910477
# e    162754.791419
# dtype: float64

# %%
s.iloc[1:]
# Out:
# b     0.508840
# c     0.491365
# d    -0.093787
# e    12.000000
# dtype: float64

# %%
s.iloc[:-1]
# Out:
# a   -0.303398
# b    0.508840
# c    0.491365
# d   -0.093787
# dtype: float64

# %%
s.iloc[1:] + s.iloc[:-1]
# Out:
# a         NaN
# b    1.017681
# c    0.982730
# d   -0.187574
# e         NaN
# dtype: float64

# %% [markdown]
# name attribute

# %%
s = pd.Series(np.random.randn(5), name="something")

# %%
s
# Out:
# 0   -0.585108
# 1    1.960112
# 2    0.402963
# 3   -1.093949
# 4    0.354292
# Name: something, dtype: float64

# %%
s.name
# Out:
# 'something'

# %%
s
# Out:
# 0   -0.585108
# 1    1.960112
# 2    0.402963
# 3   -1.093949
# 4    0.354292
# Name: something, dtype: float64

# %%
s.rename("different")
# Out:
# 0   -0.585108
# 1    1.960112
# 2    0.402963
# 3   -1.093949
# 4    0.354292
# Name: different, dtype: float64

# %%
s
# Out:
# 0   -0.585108
# 1    1.960112
# 2    0.402963
# 3   -1.093949
# 4    0.354292
# Name: something, dtype: float64

# %% [markdown]
# dataframe

# %%
d = {
    "one": pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
    "two": pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])
}

# %%
d
# Out:
# {'one': a    1.0
#  b    2.0
#  c    3.0
#  dtype: float64,
#  'two': a    1.0
#  b    2.0
#  c    3.0
#  d    4.0
#  dtype: float64}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
pd.DataFrame(d, index=['d', 'b', 'a'])
# Out:
#    one  two
# d  NaN  4.0
# b  2.0  2.0
# a  1.0  1.0

# %%
pd.DataFrame(d, index=['d', 'b', 'a'], columns=['two', 'three'])
# Out:
#    two three
# d  4.0   NaN
# b  2.0   NaN
# a  1.0   NaN

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
d = {"one": [1, 2, 3, 4], "two": [4, 3., 2, 1]}

# %%
pd.DataFrame(d)
# Out:
#    one  two
# 0    1  4.0
# 1    2  3.0
# 2    3  2.0
# 3    4  1.0

# %%
pd.DataFrame(d).dtypes
# Out:
# one      int64
# two    float64
# dtype: object

# %%
pd.DataFrame(d, index=["a", "b", "c", "d"])
# Out:
#    one  two
# a    1  4.0
# b    2  3.0
# c    3  2.0
# d    4  1.0

# %%
data = np.zeros((2, ), dtype=[("A", "i4"), ("B", "f4"), ("C", "S10")])

# %%
data
# Out:
# array([(0, 0., b''), (0, 0., b'')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
pd.DataFrame(data)
# Out:
#    A    B    C
# 0  0  0.0  b''
# 1  0  0.0  b''

# %%
pd.DataFrame(data, index=["first", "second"])
# Out:
#         A    B    C
# first   0  0.0  b''
# second  0  0.0  b''

# %%
pd.DataFrame(data, columns=["C", "B", "A"])
# Out:
#      C    B  A
# 0  b''  0.0  0
# 1  b''  0.0  0

# %%
data2 = [{"a": 1, "b": 2}, {"a": 5, "b": 10, "c": 20}]

pd.DataFrame(data2)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
pd.DataFrame(data2, index=["first", "second"])
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %%
pd.DataFrame(data2, columns=["a", "b"])
# Out:
#    a   b
# 0  1   2
# 1  5  10

# %%
pd.DataFrame(
    {
        ("a", "b"): {("A", "B"): 1, ("A", "C"): 2},
        ("a", "a"): {("A", "C"): 3, ("A", "B"): 4},
        ("a", "c"): {("A", "B"): 5, ("A", "C"): 6},
        ("b", "a"): {("A", "C"): 7, ("A", "B"): 8},
        ("b", "b"): {("A", "D"): 9, ("A", "B"): 10},
    }
)
# Out:
#        a              b
#        b    a    c    a     b
# A B  1.0  4.0  5.0  8.0  10.0
#   C  2.0  3.0  6.0  7.0   NaN
#   D  NaN  NaN  NaN  NaN   9.0

# %%
pd.DataFrame(
    {
        ("a", "b"): {("A", "B"): 1, ("A", "C"): 2},
        ("a", "a"): {("A", "C"): 3, ("A", "B"): 4},
        ("a", "c"): {("A", "B"): 5, ("A", "C"): 6},
        ("b", "a"): {("C", "A"): 7, ("A", "B"): 8},
        ("b", "b"): {("A", "D"): 9, ("A", "B"): 10},
    }
)
# Out:
#        a              b
#        b    a    c    a     b
# A B  1.0  4.0  5.0  8.0  10.0
#   C  2.0  3.0  6.0  NaN   NaN
# C A  NaN  NaN  NaN  7.0   NaN
# A D  NaN  NaN  NaN  NaN   9.0

# %%
ser = pd.Series(range(3), index=list('abc'), name="ser")

# %%
ser
# Out:
# a    0
# b    1
# c    2
# Name: ser, dtype: int64

# %%
pd.DataFrame(ser)
# Out:
#    ser
# a    0
# b    1
# c    2

# %%
from collections import namedtuple

# %%
Point = namedtuple("Point", "x y")

# %%
pd.DataFrame([Point(0, 0),  Point(0, 3), (2, 3)])
# Out:
#    x  y
# 0  0  0
# 1  0  3
# 2  2  3

# %%
Point3d = namedtuple("Point3D", "x y z")
pd.DataFrame([Point3d(0, 0, 0), Point(0, 3), Point3d(1, 2, 3)])
# Out:
#    x  y    z
# 0  0  0  0.0
# 1  0  3  NaN
# 2  1  2  3.0

# %%
from dataclasses import make_dataclass

# %%
Point = make_dataclass("Point", [("x", int), ("y", int)])

# %%
pd.DataFrame([Point(0, 0), Point(0, 3), Point(1, 2)])
# Out:
#    x  y
# 0  0  0
# 1  0  3
# 2  1  2

# %%
d = dict([("A", [1, 2, 3]), ("B", [4, 5, 6])])

# %%
d
# Out:
# {'A': [1, 2, 3], 'B': [4, 5, 6]}

# %%
pd.DataFrame.from_dict(d)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
pd.DataFrame.from_dict(d, orient="index")
# Out:
#    0  1  2
# A  1  2  3
# B  4  5  6

# %%
df = pd.DataFrame.from_dict(d, orient="index", columns=["one", "two", "three"])

# %%
data
# Out:
# array([(0, 0., b''), (0, 0., b'')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
pd.DataFrame.from_records(data, index="C")
# Out:
#      A    B
# C
# b''  0  0.0
# b''  0  0.0

# %%
df
# Out:
#    one  two  three
# A    1    2      3
# B    4    5      6

# %%
df["one"]
# Out:
# A    1
# B    4
# Name: one, dtype: int64

# %%
df["four"] = df["one"] * df["two"]

# %%
df
# Out:
#    one  two  three  four
# A    1    2      3     2
# B    4    5      6    20

# %%
df["flag"] = df["one"] > 2

# %%
df
# Out:
#    one  two  three  four   flag
# A    1    2      3     2  False
# B    4    5      6    20   True

# %%
del df["two"]

# %%
three = df.pop("three")

# %%
df
# Out:
#    one  four   flag
# A    1     2  False
# B    4    20   True

# %%
three
# Out:
# A    3
# B    6
# Name: three, dtype: int64

# %%
df["foo"] = "bar"

# %%
df
# Out:
#    one  four   flag  foo
# A    1     2  False  bar
# B    4    20   True  bar

# %%
type(df["one"][:1])
# Out:
# pandas.core.series.Series

# %%
type(df["one"][0])
# Out:
# /tmp/ipykernel_6930/2656318874.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type(df["one"][0])
# numpy.int64

# %%
df["one_trunc"] = df["one"][:1]

# %%
df
# Out:
#    one  four   flag  foo  one_trunc
# A    1     2  False  bar        1.0
# B    4    20   True  bar        NaN

# %%
df.insert(1, "new col", df["one"])

# %%
df
# Out:
#    one  new col  four   flag  foo  one_trunc
# A    1        1     2  False  bar        1.0
# B    4        4    20   True  bar        NaN

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris(as_frame=True)
iris = iris.frame

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iris.assign(sepal_ratio = iris['sepal length (cm)'] / iris['sepal width (cm)'])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target  sepal_ratio
# ...

# %%
iris.assign(sepal_ratio = lambda x: x['sepal length (cm)'] / x['sepal width (cm)'])
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target  sepal_ratio
# ...

# %%
(
    iris.query(" `sepal length (cm)` > 5")
    .assign(
        sepal_ratio = lambda x: x['sepal width (cm)'] / x['sepal length (cm)'],
        petal_ratio = lambda x: x['petal width (cm)'] / x['petal length (cm)'],
    )
    .plot(kind='scatter', x='sepal_ratio', y='petal_ratio')
)
# Out:
# <Axes: xlabel='sepal_ratio', ylabel='petal_ratio'>

# %%
dfa = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})

# %%
dfa
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
dfa.assign(C=lambda x: x["A"] + x["B"], D=lambda x: x["A"] + x["C"])
# Out:
#    A  B  C   D
# 0  1  4  5   6
# 1  2  5  7   9
# 2  3  6  9  12

# %%
dfa
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df = pd.DataFrame({"one": [1, 2, 3], "two": [4, 5, 6]}, index=["a", "b", "c"])

# %%
df.loc["b"]
# Out:
# one    2
# two    5
# Name: b, dtype: int64

# %%
df.iloc[1]
# Out:
# one    2
# two    5
# Name: b, dtype: int64

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=list("ABCD"))

# %%
df
# Out:
#           A         B         C         D
# 0  1.141186 -0.188199 -1.006245 -0.744665
# 1 -0.637417 -2.281879 -0.905780  0.599907
# 2  1.778121 -0.946813  0.189504 -1.031477
# 3 -1.527575 -0.642816 -0.994904 -0.226596
# 4 -0.623280 -1.338206  0.131092  2.239549
# 5 -0.276962  0.608641  0.579501  0.066601
# 6  0.037147  0.624766 -0.553481  0.721739
# 7  0.240695  1.906387  0.091110  0.625761
# 8  1.992943  0.146591  1.657759 -1.111071
# 9 -1.168364  0.314261  1.236255 -1.452722

# %%
df2 = pd.DataFrame(np.random.randn(7, 3), columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0  1.456471 -0.737173  1.110001
# 1  0.598593 -0.262294  1.220065
# 2  1.338741 -0.514165  0.156574
# 3  0.276505  0.437575  0.548479
# 4  0.025250 -0.896989 -0.449632
# 5  0.211162  0.889420  1.746211
# 6 -1.951856  2.226626  0.900758

# %%
df + df2
# Out:
#           A         B         C   D
# 0  2.597657 -0.925372  0.103756 NaN
# 1 -0.038824 -2.544173  0.314285 NaN
# 2  3.116861 -1.460978  0.346077 NaN
# 3 -1.251069 -0.205241 -0.446425 NaN
# 4 -0.598030 -2.235195 -0.318540 NaN
# 5 -0.065799  1.498061  2.325712 NaN
# 6 -1.914708  2.851392  0.347276 NaN
# 7       NaN       NaN       NaN NaN
# 8       NaN       NaN       NaN NaN
# 9       NaN       NaN       NaN NaN

# %%
df - df.iloc[0]
# Out:
#           A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000
# 1 -1.778603 -2.093681  0.100465  1.344572
# 2  0.636935 -0.758614  1.195749 -0.286812
# 3 -2.668761 -0.454618  0.011342  0.518070
# 4 -1.764466 -1.150007  1.137337  2.984215
# 5 -1.418148  0.796840  1.585746  0.811266
# 6 -1.104038  0.812965  0.452764  1.466405
# 7 -0.900491  2.094586  1.097356  1.370426
# 8  0.851757  0.334790  2.664004 -0.366406
# 9 -2.309550  0.502460  2.242501 -0.708057

# %%
Indexing / selection
