# %%
import torch
import numpy as np

# %%
data = [[1, 2], [3, 4]]
x = torch.tensor(data)

# %%
np_array = np.array(data)
x_np = torch.tensor(np_array)

# %%
x_ones = torch.ones_like(x_np)
x_ones
# Out:
# tensor([[1, 1],
#         [1, 1]])

# %%
x_rand = torch.rand_like(x, dtype=torch.float)

# %%
x_rand
# Out:
# tensor([[0.3054, 0.2345],
#         [0.7139, 0.6117]])

# %%
shape = (2, 3, )
rand_tensor = torch.rand(shape)
ones_tensor = torch.ones(shape)
zeros_tensor = torch.zeros(shape)
ones_tensor, zeros_tensor, rand_tensor
# Out:
# (tensor([[1., 1., 1.],
#          [1., 1., 1.]]),
#  tensor([[0., 0., 0.],
#          [0., 0., 0.]]),
#  tensor([[0.5033, 0.4228, 0.6852],
#          [0.6852, 0.8671, 0.8413]]))

# %%
tensor = torch.rand(3, 4)
tensor.shape, tensor.dtype, tensor.device
# Out:
# (torch.Size([3, 4]), torch.float32, device(type='cpu'))

# %%
if torch.accelerator.is_available():
    print('meh')

# %%
tensor = torch.rand(4, 4)
tensor
# Out:
# tensor([[0.5889, 0.4610, 0.4393, 0.4638],
#         [0.3295, 0.0699, 0.6495, 0.2567],
#         [0.0439, 0.5765, 0.3470, 0.1344],
#         [0.9588, 0.4673, 0.4846, 0.2864]])

# %%
tensor[0]
# Out:
# tensor([0.5889, 0.4610, 0.4393, 0.4638])

# %%
tensor[:, 0]
# Out:
# tensor([0.5889, 0.3295, 0.0439, 0.9588])

# %%
tensor[..., -1]
# Out:
# tensor([0.4638, 0.2567, 0.1344, 0.2864])

# %%
tensor[:, 1] = 0
tensor
# Out:
# tensor([[0.5889, 0.0000, 0.4393, 0.4638],
#         [0.3295, 0.0000, 0.6495, 0.2567],
#         [0.0439, 0.0000, 0.3470, 0.1344],
#         [0.9588, 0.0000, 0.4846, 0.2864]])

# %%
tensor.shape
# Out:
# torch.Size([4, 4])

# %%
torch.cat([tensor, tensor], dim=1)
# Out:
# tensor([[0.5889, 0.0000, 0.4393, 0.4638, 0.5889, 0.0000, 0.4393, 0.4638],
#         [0.3295, 0.0000, 0.6495, 0.2567, 0.3295, 0.0000, 0.6495, 0.2567],
#         [0.0439, 0.0000, 0.3470, 0.1344, 0.0439, 0.0000, 0.3470, 0.1344],
#         [0.9588, 0.0000, 0.4846, 0.2864, 0.9588, 0.0000, 0.4846, 0.2864]])

# %%
y1 = tensor @ tensor.T
y1
# Out:
# tensor([[0.7549, 0.5984, 0.2406, 0.9104],
#         [0.5984, 0.5963, 0.2743, 0.7042],
#         [0.2406, 0.2743, 0.1404, 0.2487],
#         [0.9104, 0.7042, 0.2487, 1.2362]])

# %%
y2 = tensor.matmul(tensor.T)

# %%
y3 = torch.rand_like(y1)
y3
# Out:
# tensor([[0.2823, 0.9034, 0.6712, 0.8991],
#         [0.1380, 0.5657, 0.0823, 0.9352],
#         [0.2326, 0.6647, 0.3536, 0.6451],
#         [0.7000, 0.8410, 0.7795, 0.6917]])

# %%
torch.matmul(tensor, tensor.T, out=y3)
# Out:
# tensor([[0.7549, 0.5984, 0.2406, 0.9104],
#         [0.5984, 0.5963, 0.2743, 0.7042],
#         [0.2406, 0.2743, 0.1404, 0.2487],
#         [0.9104, 0.7042, 0.2487, 1.2362]])

# %%
y3
# Out:
# tensor([[0.7549, 0.5984, 0.2406, 0.9104],
#         [0.5984, 0.5963, 0.2743, 0.7042],
#         [0.2406, 0.2743, 0.1404, 0.2487],
#         [0.9104, 0.7042, 0.2487, 1.2362]])

# %%
tensor * tensor
# Out:
# tensor([[0.3468, 0.0000, 0.1930, 0.2151],
#         [0.1086, 0.0000, 0.4218, 0.0659],
#         [0.0019, 0.0000, 0.1204, 0.0181],
#         [0.9194, 0.0000, 0.2348, 0.0820]])

# %%
tensor.mul(tensor)
# Out:
# tensor([[0.3468, 0.0000, 0.1930, 0.2151],
#         [0.1086, 0.0000, 0.4218, 0.0659],
#         [0.0019, 0.0000, 0.1204, 0.0181],
#         [0.9194, 0.0000, 0.2348, 0.0820]])

# %%
agg = tensor.sum()

# %%
agg
# Out:
# tensor(4.9828)

# %%
type(agg)
# Out:
# torch.Tensor

# %%
agg.item()
# Out:
# 4.982810020446777

# %%
type(agg.item())
# Out:
# float

# %%
tensor
# Out:
# tensor([[0.5889, 0.0000, 0.4393, 0.4638],
#         [0.3295, 0.0000, 0.6495, 0.2567],
#         [0.0439, 0.0000, 0.3470, 0.1344],
#         [0.9588, 0.0000, 0.4846, 0.2864]])

# %%
tensor.add_(5)
# Out:
# tensor([[5.5889, 5.0000, 5.4393, 5.4638],
#         [5.3295, 5.0000, 5.6495, 5.2567],
#         [5.0438, 5.0000, 5.3470, 5.1344],
#         [5.9588, 5.0000, 5.4846, 5.2864]])

# %%
t = torch.ones(5)

# %%
t
# Out:
# tensor([1., 1., 1., 1., 1.])

# %%
# Bridge with NumPy
n = t.numpy()

# %%
n
# Out:
# array([1., 1., 1., 1., 1.], dtype=float32)

# %%
t.add_(1)
# Out:
# tensor([2., 2., 2., 2., 2.])

# %%
n
# Out:
# array([2., 2., 2., 2., 2.], dtype=float32)

# %%
t
# Out:
# tensor([2., 2., 2., 2., 2.])

# %%
n = np.ones(5)
t = torch.from_numpy(n)

# %%
np.add(n, 1, out=n)
# Out:
# array([2., 2., 2., 2., 2.])

# %%
n
# Out:
# array([2., 2., 2., 2., 2.])

# %%
t
# Out:
# tensor([2., 2., 2., 2., 2.], dtype=torch.float64)
