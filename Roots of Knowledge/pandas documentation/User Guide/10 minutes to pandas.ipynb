# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.813399  0.562514  0.840285 -0.303228
# 2013-01-02 -0.620399  0.350548  0.004386  0.248320
# 2013-01-03 -0.288518 -1.904786 -2.179893 -0.484495
# 2013-01-04  1.689702 -1.703145  1.612877 -0.860718
# 2013-01-05 -0.416485 -1.609066 -0.866957  0.856773
# 2013-01-06  1.089825  0.032371  1.317983  0.001747

# %%
df = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head(2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo

# %%
df.tail(1)
# Out:
#      A          B    C  D      E    F
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df.to_numpy().dtype
# Out:
# dtype('O')

# %%
df.to_numpy().dtype # object => as it fits all
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2013-01-02 00:00:00  2013-01-02 00:00:00  2013-01-02 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                  1.0
# B  2013-01-02 00:00:00
# C                  1.0
# D                    3
# E                train
# F                  foo

# %%
df.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.sort_index(ascending=False)
# Out:
#      A          B    C  D      E    F
# 3  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 0  1.0 2013-01-02  1.0  3   test  foo

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#      F      E  D    C          B    A
# 0  foo   test  3  1.0 2013-01-02  1.0
# 1  foo  train  3  1.0 2013-01-02  1.0
# 2  foo   test  3  1.0 2013-01-02  1.0
# 3  foo  train  3  1.0 2013-01-02  1.0

# %%
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.329452  0.075246 -0.057852 -0.730614
# 2013-01-02 -0.309988 -0.031991  1.091681  1.115255
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659
# 2013-01-04 -0.882402  0.211132  1.528173 -0.943440
# 2013-01-05  0.445173  0.753380  0.335725 -1.604177
# 2013-01-06  1.423606  0.452894 -0.489126  0.017875

# %%
df.sort_values("B")
# Out:
#                    A         B         C         D
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659
# 2013-01-02 -0.309988 -0.031991  1.091681  1.115255
# 2013-01-01  1.329452  0.075246 -0.057852 -0.730614
# 2013-01-04 -0.882402  0.211132  1.528173 -0.943440
# 2013-01-06  1.423606  0.452894 -0.489126  0.017875
# 2013-01-05  0.445173  0.753380  0.335725 -1.604177

# %%
df["A"]
# Out:
# 2013-01-01    1.329452
# 2013-01-02   -0.309988
# 2013-01-03    0.271573
# 2013-01-04   -0.882402
# 2013-01-05    0.445173
# 2013-01-06    1.423606
# Freq: D, Name: A, dtype: float64

# %%
type(df["A"])
# Out:
# pandas.core.series.Series

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  1.329452  0.075246 -0.057852 -0.730614
# 2013-01-02 -0.309988 -0.031991  1.091681  1.115255
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659

# %%
df["20130101":"20130103"]
# Out:
#                    A         B         C         D
# 2013-01-01  1.329452  0.075246 -0.057852 -0.730614
# 2013-01-02 -0.309988 -0.031991  1.091681  1.115255
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659

# %%
df.loc["20130103"]
# Out:
# A    0.271573
# B   -0.358834
# C    1.475016
# D   -1.107659
# Name: 2013-01-03 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  1.329452  0.075246
# 2013-01-02 -0.309988 -0.031991
# 2013-01-03  0.271573 -0.358834
# 2013-01-04 -0.882402  0.211132
# 2013-01-05  0.445173  0.753380
# 2013-01-06  1.423606  0.452894

# %%
df.loc["20130102":"20130104", "A": "B"]
# Out:
#                    A         B
# 2013-01-02 -0.309988 -0.031991
# 2013-01-03  0.271573 -0.358834
# 2013-01-04 -0.882402  0.211132

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(1.3294523736080044)

# %%
df.iloc[3]
# Out:
# A   -0.882402
# B    0.211132
# C    1.528173
# D   -0.943440
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.329452  0.075246 -0.057852 -0.730614
# 2013-01-02 -0.309988 -0.031991  1.091681  1.115255
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659
# 2013-01-04 -0.882402  0.211132  1.528173 -0.943440
# 2013-01-05  0.445173  0.753380  0.335725 -1.604177
# 2013-01-06  1.423606  0.452894 -0.489126  0.017875

# %%
df.iloc[3:5]
# Out:
#                    A         B         C         D
# 2013-01-04 -0.882402  0.211132  1.528173 -0.943440
# 2013-01-05  0.445173  0.753380  0.335725 -1.604177

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.882402  0.211132
# 2013-01-05  0.445173  0.753380

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -0.309988  1.091681
# 2013-01-03  0.271573  1.475016
# 2013-01-05  0.445173  0.335725

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.309988 -0.031991  1.091681  1.115255
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.075246 -0.057852
# 2013-01-02 -0.031991  1.091681
# 2013-01-03 -0.358834  1.475016
# 2013-01-04  0.211132  1.528173
# 2013-01-05  0.753380  0.335725
# 2013-01-06  0.452894 -0.489126

# %%
df.iloc[1, 1]
# Out:
# np.float64(-0.03199089039035163)

# %%
df.iat[1, 1]
# Out:
# np.float64(-0.03199089039035163)

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(1.3294523736080044)

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.329452  0.075246 -0.057852 -0.730614
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659
# 2013-01-05  0.445173  0.753380  0.335725 -1.604177
# 2013-01-06  1.423606  0.452894 -0.489126  0.017875

# %%
df["A"] > 0
# Out:
# 2013-01-01     True
# 2013-01-02    False
# 2013-01-03     True
# 2013-01-04    False
# 2013-01-05     True
# 2013-01-06     True
# Freq: D, Name: A, dtype: bool

# %%
df > 0
# Out:
#                 A      B      C      D
# 2013-01-01   True   True  False  False
# 2013-01-02  False  False   True   True
# 2013-01-03   True  False   True  False
# 2013-01-04  False   True   True  False
# 2013-01-05   True   True   True  False
# 2013-01-06   True   True  False   True

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  1.329452  0.075246       NaN       NaN
# 2013-01-02       NaN       NaN  1.091681  1.115255
# 2013-01-03  0.271573       NaN  1.475016       NaN
# 2013-01-04       NaN  0.211132  1.528173       NaN
# 2013-01-05  0.445173  0.753380  0.335725       NaN
# 2013-01-06  1.423606  0.452894       NaN  0.017875

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  1.329452  0.075246 -0.057852 -0.730614    one
# 2013-01-02 -0.309988 -0.031991  1.091681  1.115255    one
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659    two
# 2013-01-04 -0.882402  0.211132  1.528173 -0.943440  three
# 2013-01-05  0.445173  0.753380  0.335725 -1.604177   four
# 2013-01-06  1.423606  0.452894 -0.489126  0.017875  three

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.329452  0.075246 -0.057852 -0.730614
# 2013-01-02 -0.309988 -0.031991  1.091681  1.115255
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659
# 2013-01-04 -0.882402  0.211132  1.528173 -0.943440
# 2013-01-05  0.445173  0.753380  0.335725 -1.604177
# 2013-01-06  1.423606  0.452894 -0.489126  0.017875

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.271573 -0.358834  1.475016 -1.107659   two
# 2013-01-05  0.445173  0.753380  0.335725 -1.604177  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(1.3294523736080044)

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.000000 -0.057852  5.0
# 2013-01-02 -0.309988 -0.031991  1.091681  5.0
# 2013-01-03  0.271573 -0.358834  1.475016  5.0
# 2013-01-04 -0.882402  0.211132  1.528173  5.0
# 2013-01-05  0.445173  0.753380  0.335725  5.0
# 2013-01-06  1.423606  0.452894 -0.489126  5.0

# %%
df["F"] = s1

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.057852  5.0  NaN
# 2013-01-02 -0.309988 -0.031991  1.091681  5.0  1.0
# 2013-01-03  0.271573 -0.358834  1.475016  5.0  2.0
# 2013-01-04 -0.882402  0.211132  1.528173  5.0  3.0
# 2013-01-05  0.445173  0.753380  0.335725  5.0  4.0
# 2013-01-06  1.423606  0.452894 -0.489126  5.0  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.057852 -5.0  NaN
# 2013-01-02 -0.309988 -0.031991 -1.091681 -5.0 -1.0
# 2013-01-03 -0.271573 -0.358834 -1.475016 -5.0 -2.0
# 2013-01-04 -0.882402 -0.211132 -1.528173 -5.0 -3.0
# 2013-01-05 -0.445173 -0.753380 -0.335725 -5.0 -4.0
# 2013-01-06 -1.423606 -0.452894 -0.489126 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["e"])
df1
# Out:
#                    A         B         C    D    F   e
# 2013-01-01  0.000000  0.000000 -0.057852  5.0  NaN NaN
# 2013-01-02 -0.309988 -0.031991  1.091681  5.0  1.0 NaN
# 2013-01-03  0.271573 -0.358834  1.475016  5.0  2.0 NaN
# 2013-01-04 -0.882402  0.211132  1.528173  5.0  3.0 NaN

# %%
df1.loc[dates[0]: dates[1], "E"] = 1
df1
# Out:
#                    A         B         C    D    F   e    E
# 2013-01-01  0.000000  0.000000 -0.057852  5.0  NaN NaN  1.0
# 2013-01-02 -0.309988 -0.031991  1.091681  5.0  1.0 NaN  1.0
# 2013-01-03  0.271573 -0.358834  1.475016  5.0  2.0 NaN  NaN
# 2013-01-04 -0.882402  0.211132  1.528173  5.0  3.0 NaN  NaN

# %%
df1.loc[dates[0]: dates[1], "E"] = 2

# %%
df1
# Out:
#                    A         B         C    D    F   e    E
# 2013-01-01  0.000000  0.000000 -0.057852  5.0  NaN NaN  2.0
# 2013-01-02 -0.309988 -0.031991  1.091681  5.0  1.0 NaN  2.0
# 2013-01-03  0.271573 -0.358834  1.475016  5.0  2.0 NaN  NaN
# 2013-01-04 -0.882402  0.211132  1.528173  5.0  3.0 NaN  NaN

# %%
df1.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, F, e, E]
# Index: []

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    e    E
# 2013-01-01  0.000000  0.000000 -0.057852  5.0  5.0  5.0  2.0
# 2013-01-02 -0.309988 -0.031991  1.091681  5.0  1.0  5.0  2.0
# 2013-01-03  0.271573 -0.358834  1.475016  5.0  2.0  5.0  5.0
# 2013-01-04 -0.882402  0.211132  1.528173  5.0  3.0  5.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F     e      E
# 2013-01-01  False  False  False  False   True  True  False
# 2013-01-02  False  False  False  False  False  True  False
# 2013-01-03  False  False  False  False  False  True   True
# 2013-01-04  False  False  False  False  False  True   True

# %%
df
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000 -0.057852  5.0  NaN  2.0
# 2013-01-02 -0.309988 -0.031991  1.091681  5.0  1.0  2.0
# 2013-01-03  0.271573 -0.358834  1.475016  5.0  2.0  NaN
# 2013-01-04 -0.882402  0.211132  1.528173  5.0  3.0  NaN
# 2013-01-05  0.445173  0.753380  0.335725  5.0  4.0  NaN
# 2013-01-06  1.423606  0.452894 -0.489126  5.0  5.0  NaN

# %%
df.mean()
# Out:
# A    0.157994
# B    0.171097
# C    0.647269
# D    5.000000
# F    3.000000
# E    2.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.388430
# 2013-01-02    1.458284
# 2013-01-03    1.677551
# 2013-01-04    1.771380
# 2013-01-05    2.106855
# 2013-01-06    2.277475
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F   E
# 2013-01-01       NaN       NaN       NaN  NaN  NaN NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN NaN
# 2013-01-03 -0.728427 -1.358834  0.475016  4.0  1.0 NaN
# 2013-01-04 -3.882402 -2.788868 -1.471827  2.0  0.0 NaN
# 2013-01-05 -4.554827 -4.246620 -4.664275  0.0 -1.0 NaN
# 2013-01-06       NaN       NaN       NaN  NaN  NaN NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A     0.884764
# B     0.958142
# C     3.624708
# D    28.000000
# F    16.800000
# E    11.200000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A          B           C      D      F      E
# 2013-01-01    0.000000   0.000000   -5.854578  506.0    NaN  202.4
# 2013-01-02  -31.370782  -3.237478  110.478082  506.0  101.2  202.4
# 2013-01-03   27.483160 -36.313968  149.271617  506.0  202.4    NaN
# 2013-01-04  -89.299117  21.366521  154.651059  506.0  303.6    NaN
# 2013-01-05   45.051521  76.242012   33.975341  506.0  404.8    NaN
# 2013-01-06  144.068944  45.832877  -49.499576  506.0  506.0    NaN

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    3
# 1    0
# 2    5
# 3    1
# 4    3
# 5    6
# 6    3
# 7    1
# 8    3
# 9    1
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    4
# 1    3
# 0    1
# 5    1
# 6    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
a = np.random.randn(10, 4)
b = np.random.randn(10, 4)

# %%
np.hstack((a, b)).shape
# Out:
# (10, 8)

# %%
np.vstack((a, b)).shape
# Out:
# (20, 4)

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.344395 -1.387017 -0.398701  2.308154
# 1  0.409964  0.283042  0.868013  0.769581
# 2 -1.814412 -0.339916 -0.698728 -0.193310
# 3  0.266749 -1.271420 -0.299521 -0.081225
# 4 -0.384886  1.276187  1.085594 -1.110575
# 5 -0.397431 -0.870910  0.093963  1.476707
# 6 -0.359658 -0.114765 -1.898964 -1.031023
# 7 -0.205223 -0.223611  2.292279 -0.489503
# 8 -0.102911  0.533961  2.527238 -1.415412
# 9 -0.368259 -1.010729  0.989205  0.711115

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0  0.344395 -1.387017 -0.398701  2.308154
#  1  0.409964  0.283042  0.868013  0.769581
#  2 -1.814412 -0.339916 -0.698728 -0.193310,
#            0         1         2         3
#  3  0.266749 -1.271420 -0.299521 -0.081225
#  4 -0.384886  1.276187  1.085594 -1.110575
#  5 -0.397431 -0.870910  0.093963  1.476707
#  6 -0.359658 -0.114765 -1.898964 -1.031023,
#            0         1         2         3
#  7 -0.205223 -0.223611  2.292279 -0.489503
#  8 -0.102911  0.533961  2.527238 -1.415412
#  9 -0.368259 -1.010729  0.989205  0.711115]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.344395 -1.387017 -0.398701  2.308154
# 1  0.409964  0.283042  0.868013  0.769581
# 2 -1.814412 -0.339916 -0.698728 -0.193310
# 3  0.266749 -1.271420 -0.299521 -0.081225
# 4 -0.384886  1.276187  1.085594 -1.110575
# 5 -0.397431 -0.870910  0.093963  1.476707
# 6 -0.359658 -0.114765 -1.898964 -1.031023
# 7 -0.205223 -0.223611  2.292279 -0.489503
# 8 -0.102911  0.533961  2.527238 -1.415412
# 9 -0.368259 -1.010729  0.989205  0.711115

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [3, 4]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     3
# 1  foo     4

# %%
pd.merge(left, right, on="key") # sql join
# Out:
#    key  lval  rval
# 0  foo     1     3
# 1  foo     1     4
# 2  foo     2     3
# 3  foo     2     4

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ### Grouping

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one -0.317660 -2.619513
# 1  bar    one  0.803273  0.203080
# 2  foo    two -0.465930  1.113852
# 3  bar  three  1.118896 -0.902103
# 4  foo    two -1.186737  0.617464
# 5  bar    two -0.977010  0.363150
# 6  foo    one  1.119197  0.732951
# 7  foo  three  0.540966 -2.245091

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar  0.945159 -0.335873
# foo -0.310164 -2.400337

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    0.803273  0.203080
#     three  1.118896 -0.902103
#     two   -0.977010  0.363150
# foo one    0.801537 -1.886562
#     three  0.540966 -2.245091
#     two   -1.652667  1.731316

# %% [markdown]
# ## Reshaping

# %% [markdown]
# ### Stack

# %%
arrays = [
    ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df
# Out:
#                      A         B
# first second
# bar   one    -1.133865  1.433558
#       two    -1.814774 -1.111128
# baz   one    -0.928509 -0.450601
#       two     0.857130 -0.298480
# foo   one    -1.019487  2.054922
#       two    -0.740854  0.439087
# qux   one    -1.393106  0.730321
#       two     0.970494  1.108231

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -1.133865  1.433558
#       two    -1.814774 -1.111128
# baz   one    -0.928509 -0.450601
#       two     0.857130 -0.298480

# %%
stacked = df2.stack(future_stack=True)
stacked
# Out:
# first  second
# bar    one     A   -1.133865
#                B    1.433558
#        two     A   -1.814774
#                B   -1.111128
# baz    one     A   -0.928509
#                B   -0.450601
#        two     A    0.857130
#                B   -0.298480
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -1.133865  1.433558
#       two    -1.814774 -1.111128
# baz   one    -0.928509 -0.450601
#       two     0.857130 -0.298480

# %%
stacked
# Out:
# first  second
# bar    one     A   -1.133865
#                B    1.433558
#        two     A   -1.814774
#                B   -1.111128
# baz    one     A   -0.928509
#                B   -0.450601
#        two     A    0.857130
#                B   -0.298480
# dtype: float64

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -1.133865 -1.814774
#       B  1.433558 -1.111128
# baz   A -0.928509  0.857130
#       B -0.450601 -0.298480

# %%
stacked
# Out:
# first  second
# bar    one     A   -1.133865
#                B    1.433558
#        two     A   -1.814774
#                B   -1.111128
# baz    one     A   -0.928509
#                B   -0.450601
#        two     A    0.857130
#                B   -0.298480
# dtype: float64

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -1.133865 -0.928509
#        B  1.433558 -0.450601
# two    A -1.814774  0.857130
#        B -1.111128 -0.298480

# %%
df = pd.DataFrame({
    "A": ["one", "one", "two", "three"] * 3,
    "B": ["A", "B", "C"] * 4,
    "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
    "D": np.random.randn(12),
    "E": np.random.randn(12),
})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.659600  0.602640
# 1     one  B  foo  1.978433  0.551662
# 2     two  C  foo  2.005655 -0.696351
# 3   three  A  bar -0.466653  0.961613
# 4     one  B  bar -0.818685  1.807737
# 5     one  C  bar -0.935411  1.014095
# 6     two  A  foo  1.818945  0.796805
# 7   three  B  foo  1.538353  0.726618
# 8     one  C  foo  0.322776 -0.290601
# 9     one  A  bar  0.194658  1.248212
# 10    two  B  bar -0.069898  0.354663
# 11  three  C  bar  0.102593  0.342760

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.194658 -0.659600
#       B -0.818685  1.978433
#       C -0.935411  0.322776
# three A -0.466653       NaN
#       B       NaN  1.538353
#       C  0.102593       NaN
# two   A       NaN  1.818945
#       B -0.069898       NaN
#       C       NaN  2.005655

# %%
pd.pivot_table(df, values="D", index=["A", "C"], columns=["B"])
# Out:
# B                 A         B         C
# A     C
# one   bar  0.194658 -0.818685 -0.935411
#       foo -0.659600  1.978433  0.322776
# three bar -0.466653       NaN  0.102593
#       foo       NaN  1.538353       NaN
# two   bar       NaN -0.069898       NaN
#       foo  1.818945       NaN  2.005655

# %%
pd.pivot_table(df, values="E", index=["B", "C"], columns=["A"])
# Out:
# A           one     three       two
# B C
# A bar  1.248212  0.961613       NaN
#   foo  0.602640       NaN  0.796805
# B bar  1.807737       NaN  0.354663
#   foo  0.551662  0.726618       NaN
# C bar  1.014095  0.342760       NaN
#   foo -0.290601       NaN -0.696351

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                '2012-01-01 00:00:10', '2012-01-01 00:00:11',
#                '2012-01-01 00:00:12', '2012-01-01 00:00:13',
#                '2012-01-01 00:00:14', '2012-01-01 00:00:15',
#                '2012-01-01 00:00:16', '2012-01-01 00:00:17',
#                '2012-01-01 00:00:18', '2012-01-01 00:00:19',
#                '2012-01-01 00:00:20', '2012-01-01 00:00:21',
#                '2012-01-01 00:00:22', '2012-01-01 00:00:23',
#                '2012-01-01 00:00:24', '2012-01-01 00:00:25',
#                '2012-01-01 00:00:26', '2012-01-01 00:00:27',
#                '2012-01-01 00:00:28', '2012-01-01 00:00:29',
#                '2012-01-01 00:00:30', '2012-01-01 00:00:31',
#                '2012-01-01 00:00:32', '2012-01-01 00:00:33',
#                '2012-01-01 00:00:34', '2012-01-01 00:00:35',
#                '2012-01-01 00:00:36', '2012-01-01 00:00:37',
#                '2012-01-01 00:00:38', '2012-01-01 00:00:39',
#                '2012-01-01 00:00:40', '2012-01-01 00:00:41',
#                '2012-01-01 00:00:42', '2012-01-01 00:00:43',
#                '2012-01-01 00:00:44', '2012-01-01 00:00:45',
#                '2012-01-01 00:00:46', '2012-01-01 00:00:47',
#                '2012-01-01 00:00:48', '2012-01-01 00:00:49',
#                '2012-01-01 00:00:50', '2012-01-01 00:00:51',
#                '2012-01-01 00:00:52', '2012-01-01 00:00:53',
#                '2012-01-01 00:00:54', '2012-01-01 00:00:55',
#                '2012-01-01 00:00:56', '2012-01-01 00:00:57',
#                '2012-01-01 00:00:58', '2012-01-01 00:00:59',
#                '2012-01-01 00:01:00', '2012-01-01 00:01:01',
#                '2012-01-01 00:01:02', '2012-01-01 00:01:03',
#                '2012-01-01 00:01:04', '2012-01-01 00:01:05',
#                '2012-01-01 00:01:06', '2012-01-01 00:01:07',
#                '2012-01-01 00:01:08', '2012-01-01 00:01:09',
#                '2012-01-01 00:01:10', '2012-01-01 00:01:11',
#                '2012-01-01 00:01:12', '2012-01-01 00:01:13',
#                '2012-01-01 00:01:14', '2012-01-01 00:01:15',
#                '2012-01-01 00:01:16', '2012-01-01 00:01:17',
#                '2012-01-01 00:01:18', '2012-01-01 00:01:19',
#                '2012-01-01 00:01:20', '2012-01-01 00:01:21',
#                '2012-01-01 00:01:22', '2012-01-01 00:01:23',
#                '2012-01-01 00:01:24', '2012-01-01 00:01:25',
#                '2012-01-01 00:01:26', '2012-01-01 00:01:27',
#                '2012-01-01 00:01:28', '2012-01-01 00:01:29',
#                '2012-01-01 00:01:30', '2012-01-01 00:01:31',
#                '2012-01-01 00:01:32', '2012-01-01 00:01:33',
#                '2012-01-01 00:01:34', '2012-01-01 00:01:35',
#                '2012-01-01 00:01:36', '2012-01-01 00:01:37',
#                '2012-01-01 00:01:38', '2012-01-01 00:01:39'],
#               dtype='datetime64[ns]', freq='s')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts
# Out:
# 2012-01-01 00:00:00      8
# 2012-01-01 00:00:01    385
# 2012-01-01 00:00:02     32
# 2012-01-01 00:00:03    214
# 2012-01-01 00:00:04    121
#                       ...
# 2012-01-01 00:01:35    452
# 2012-01-01 00:01:36    226
# 2012-01-01 00:01:37    203
# 2012-01-01 00:01:38     34
# 2012-01-01 00:01:39    177
# Freq: s, Length: 100, dtype: int64

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    24451
# Freq: 5min, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-03-06    0.081456
# 2012-03-07    1.311081
# 2012-03-08    0.506220
# 2012-03-09    0.987784
# 2012-03-10    0.083641
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.081456
# 2012-03-07 00:00:00+00:00    1.311081
# 2012-03-08 00:00:00+00:00    0.506220
# 2012-03-09 00:00:00+00:00    0.987784
# 2012-03-10 00:00:00+00:00    0.083641
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00    0.081456
# 2012-03-06 19:00:00-05:00    1.311081
# 2012-03-07 19:00:00-05:00    0.506220
# 2012-03-08 19:00:00-05:00    0.987784
# 2012-03-09 19:00:00-05:00    0.083641
# Freq: D, dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # Categorical

# %%
df = pd.DataFrame(
    {
        "id": [1, 2, 3, 4, 5, 6],
        "raw_grade": ["a", "b", "b", "a", "a", "e"],
    }
)

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df
# Out:
#    id raw_grade grade
# 0   1         a     a
# 1   2         b     b
# 2   3         b     b
# 3   4         a     a
# 4   5         a     a
# 5   6         e     e

# %%
df["raw_grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: raw_grade, dtype: object

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'good', 'very bad']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good
# 1   2         b       good
# 2   3         b       good
# 5   6         e   very bad

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very good    3
# good         2
# very bad     1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2012", periods=1000))
ts.cumsum().plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)
df = df.cumsum()
plt.figure()
df.plot()
plt.legend(loc='best')

# %%
df
# Out:
#                    A          B          C         D
# 2012-01-01  0.148542  -0.874199   2.057940 -0.543143
# 2012-01-02  1.917518   0.229007   2.488089 -0.758396
# 2012-01-03  0.922967   1.382227   3.161765 -1.406312
# 2012-01-04  0.594157  -0.007919   3.147345 -0.366977
# 2012-01-05  1.352212   1.901294   4.309247  0.514262
# ...              ...        ...        ...       ...
# 2014-09-22  2.146791 -61.171588  23.213613 -2.684658
# 2014-09-23  2.833217 -61.434393  22.775180 -2.879041
# 2014-09-24  3.922168 -59.852167  23.678823 -1.997882
# 2014-09-25  5.143760 -60.219347  25.021852 -2.319394
# 2014-09-26  3.174085 -58.094740  26.914645 -1.059415
#
# [1000 rows x 4 columns]

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  0  0  0  3  4
# 1           1  2  0  2  4  1
# 2           2  3  4  0  3  2
# 3           3  1  3  2  4  3
# 4           4  4  4  0  1  2
# 5           5  4  4  0  0  1
# 6           6  1  1  3  3  0
# 7           7  2  0  3  0  1
# 8           8  1  0  1  2  4
# 9           9  0  2  3  4  4

# %%
df.to_parquet('foo.parquet')

# %%
pd.read_parquet('foo.parquet')
# Out:
#    0  1  2  3  4
# 0  0  0  0  3  4
# 1  2  0  2  4  1
# 2  3  4  0  3  2
# 3  1  3  2  4  3
# 4  4  4  0  1  2
# 5  4  4  0  0  1
# 6  1  1  3  3  0
# 7  2  0  3  0  1
# 8  1  0  1  2  4
# 9  0  2  3  4  4

# %%
df.to_excel('foo.xlsx', 'Sheet1')
# Out:
# /tmp/ipykernel_4747/2986532883.py:1: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   df.to_excel('foo.xlsx', 'Sheet1')

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  0  0  0  3  4
# 1           1  2  0  2  4  1
# 2           2  3  4  0  3  2
# 3           3  1  3  2  4  3
# 4           4  4  4  0  1  2
# 5           5  4  4  0  0  1
# 6           6  1  1  3  3  0
# 7           7  2  0  3  0  1
# 8           8  1  0  1  2  4
# 9           9  0  2  3  4  4
