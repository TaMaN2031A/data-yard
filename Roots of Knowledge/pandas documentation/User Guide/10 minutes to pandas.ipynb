# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.831629  0.892281  0.963239  0.262451
# 2013-01-02  1.447795 -0.574837 -0.679315 -0.985518
# 2013-01-03  1.023591  0.074830 -0.988148  0.327019
# 2013-01-04 -0.520060 -0.195670  1.219700  2.272401
# 2013-01-05 -1.553430  0.856140 -0.080261 -0.780524
# 2013-01-06  0.853564 -0.157926 -1.144326  0.004678

# %%
df = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head(2)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo

# %%
df.tail(1)
# Out:
#      A          B    C  D      E    F
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df.to_numpy().dtype
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.to_numpy().dtype # object => as it fits all
# Out:
# dtype('O')

# %%
df.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2013-01-02 00:00:00  2013-01-02 00:00:00  2013-01-02 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                  1.0
# B  2013-01-02 00:00:00
# C                  1.0
# D                    3
# E                train
# F                  foo

# %%
df.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.sort_index(ascending=False)
# Out:
#      A          B    C  D      E    F
# 3  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 0  1.0 2013-01-02  1.0  3   test  foo

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#      F      E  D    C          B    A
# 0  foo   test  3  1.0 2013-01-02  1.0
# 1  foo  train  3  1.0 2013-01-02  1.0
# 2  foo   test  3  1.0 2013-01-02  1.0
# 3  foo  train  3  1.0 2013-01-02  1.0

# %%
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.861423  0.171110  0.341813  0.404280
# 2013-01-02  0.966717  0.558660  1.665377  0.915034
# 2013-01-03  1.742624  2.140200  0.249053  0.400376
# 2013-01-04 -0.410969 -0.989028 -1.368130  0.672689
# 2013-01-05 -0.505898  0.574863  0.479468  0.390430
# 2013-01-06  2.445020  0.281749  0.801152 -1.262993

# %%
df.sort_values("B")
# Out:
#                    A         B         C         D
# 2013-01-04 -0.410969 -0.989028 -1.368130  0.672689
# 2013-01-01 -0.861423  0.171110  0.341813  0.404280
# 2013-01-06  2.445020  0.281749  0.801152 -1.262993
# 2013-01-02  0.966717  0.558660  1.665377  0.915034
# 2013-01-05 -0.505898  0.574863  0.479468  0.390430
# 2013-01-03  1.742624  2.140200  0.249053  0.400376

# %%
df["A"]
# Out:
# 2013-01-01   -0.861423
# 2013-01-02    0.966717
# 2013-01-03    1.742624
# 2013-01-04   -0.410969
# 2013-01-05   -0.505898
# 2013-01-06    2.445020
# Freq: D, Name: A, dtype: float64

# %%
type(df["A"])
# Out:
# pandas.core.series.Series

# %%
df[0:3]
# Out:
#                    A        B         C         D
# 2013-01-01 -0.861423  0.17111  0.341813  0.404280
# 2013-01-02  0.966717  0.55866  1.665377  0.915034
# 2013-01-03  1.742624  2.14020  0.249053  0.400376

# %%
df["20130101":"20130103"]
# Out:
#                    A        B         C         D
# 2013-01-01 -0.861423  0.17111  0.341813  0.404280
# 2013-01-02  0.966717  0.55866  1.665377  0.915034
# 2013-01-03  1.742624  2.14020  0.249053  0.400376

# %%
df.loc["20130103"]
# Out:
# A    1.742624
# B    2.140200
# C    0.249053
# D    0.400376
# Name: 2013-01-03 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -0.861423  0.171110
# 2013-01-02  0.966717  0.558660
# 2013-01-03  1.742624  2.140200
# 2013-01-04 -0.410969 -0.989028
# 2013-01-05 -0.505898  0.574863
# 2013-01-06  2.445020  0.281749

# %%
df.loc["20130102":"20130104", "A": "B"]
# Out:
#                    A         B
# 2013-01-02  0.966717  0.558660
# 2013-01-03  1.742624  2.140200
# 2013-01-04 -0.410969 -0.989028
